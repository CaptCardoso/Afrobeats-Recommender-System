# %% [markdown]
# # Afrobeats Recommender

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity
from sklearn.decomposition import PCA

from scipy import sparse
import plotly.express as px
import time

# %% [markdown]
# #### EDA with Jacks Playlist

# %%
ankita= pd.read_csv('../data/ankita.csv')
ankita.head(2)
# Out:
#                 track_uri                             track_name  \
# 0  068HSvCf5MbQfhV4qqaelg  Haan Main Galat (From "Love Aaj Kal")
# 1  2aHz87L2Z4a0ZEQ7vMlH8z                      Badal Pe Paon Hai
#
#       artist_name              artist_uri  \
# 0          Pritam  1wRPtKGflJrBx9BmLsSwlU
# 1  Salim–Sulaiman  6ohaQzKaXrobAL8paLSaxq
#
#                                    album  track_pop  danceability  energy  \
# 0  Haan Main Galat (From "Love Aaj Kal")         64         0.685   0.736
# 1                          Chak De India         57         0.649   0.788
#
#    key  loudness  ...  valence    tempo            type  \
# 0    0    -5.656  ...    0.893  117.979  audio_features
# 1    9    -9.607  ...    0.869  104.999  audio_features
#
#                        id                                   uri  \
# 0  068HSvCf5MbQfhV4qqaelg  spotify:track:068HSvCf5MbQfhV4qqaelg
# 1  2aHz87L2Z4a0ZEQ7vMlH8z  spotify:track:2aHz87L2Z4a0ZEQ7vMlH8z
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/068HSvCf5MbQ...
# 1  https://api.spotify.com/v1/tracks/2aHz87L2Z4a0...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/068H...      218644
# 1  https://api.spotify.com/v1/audio-analysis/2aHz...      243931
#
#   time_signature   genre
# 0              4  ankita
# 1              4  ankita
#
# [2 rows x 25 columns]

# %%
ankita.shape
# Out:
# (8, 25)

# %%
afrobeats = pd.read_csv('../data/afrobeats.csv')
afrobeats.head(2)
# Out:
#                 track_uri           track_name artist_name  \
# 0  0mDRuZmReEm6DquPLJlcEm  Oleku (feat. Brymo)  Ice Prince
# 1  1tvi8tv0eykhNcV1WtaIqO            Move Back       5five
#
#                artist_uri                album  track_pop  danceability  \
# 0  1sSt1DqqqFLkPwfrqafVyn  Oleku (feat. Brymo)         51         0.544
# 1  37zb1JQnDV9dRLatrASEj1            Move Back         45         0.793
#
#    energy  key  loudness  ...  valence    tempo            type  \
# 0   0.730    1    -4.299  ...    0.751  162.112  audio_features
# 1   0.734   11    -9.252  ...    0.793  125.032  audio_features
#
#                        id                                   uri  \
# 0  0mDRuZmReEm6DquPLJlcEm  spotify:track:0mDRuZmReEm6DquPLJlcEm
# 1  1tvi8tv0eykhNcV1WtaIqO  spotify:track:1tvi8tv0eykhNcV1WtaIqO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0mDRuZmReEm6...
# 1  https://api.spotify.com/v1/tracks/1tvi8tv0eykh...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0mDR...      291364
# 1  https://api.spotify.com/v1/audio-analysis/1tvi...      237107
#
#   time_signature      genre
# 0              5  afrobeats
# 1              4  afrobeats
#
# [2 rows x 25 columns]

# %%
afrobeats.shape
# Out:
# (1500, 25)

# %%
df = pd.concat([afrobeats, ankita])

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#                 track_uri                 track_name   artist_name  \
# 0  0mDRuZmReEm6DquPLJlcEm        Oleku (feat. Brymo)    Ice Prince
# 1  1tvi8tv0eykhNcV1WtaIqO                  Move Back         5five
# 2  5YgyvTZmdkIfFOnj8ri8mZ                   Pakurumo        WizKid
# 3  2cWdhA4ZDBvYuHRKKIPT3k  The Matter (feat. Wizkid)  Maleek Berry
# 4  4voOsb8qpJ569JaMiGAyrl  Slow Down (feat. Wiz Kid)        R2Bees
#
#                artist_uri                                album  track_pop  \
# 0  1sSt1DqqqFLkPwfrqafVyn                  Oleku (feat. Brymo)         51
# 1  37zb1JQnDV9dRLatrASEj1                            Move Back         45
# 2  3tVQdUvClmAT7URs9V3rsp                            Superstar         49
# 3  520qA5VGL9iI0SbmEnTVNg            The Matter (feat. Wizkid)         49
# 4  0LFsP7WPfu5inz9a1amcE4  Refuse to Be Broke: Da Revolution 2         53
#
#    danceability  energy  key  loudness  ...  valence    tempo            type  \
# 0         0.544   0.730    1    -4.299  ...    0.751  162.112  audio_features
# 1         0.793   0.734   11    -9.252  ...    0.793  125.032  audio_features
# 2         0.879   0.737    2    -5.412  ...    0.967  119.990  audio_features
# 3         0.697   0.841    2    -6.782  ...    0.808  103.070  audio_features
# 4         0.520   0.717    6    -3.006  ...    0.704  135.550  audio_features
#
#                        id                                   uri  \
# 0  0mDRuZmReEm6DquPLJlcEm  spotify:track:0mDRuZmReEm6DquPLJlcEm
# 1  1tvi8tv0eykhNcV1WtaIqO  spotify:track:1tvi8tv0eykhNcV1WtaIqO
# 2  5YgyvTZmdkIfFOnj8ri8mZ  spotify:track:5YgyvTZmdkIfFOnj8ri8mZ
# 3  2cWdhA4ZDBvYuHRKKIPT3k  spotify:track:2cWdhA4ZDBvYuHRKKIPT3k
# 4  4voOsb8qpJ569JaMiGAyrl  spotify:track:4voOsb8qpJ569JaMiGAyrl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0mDRuZmReEm6...
# 1  https://api.spotify.com/v1/tracks/1tvi8tv0eykh...
# 2  https://api.spotify.com/v1/tracks/5YgyvTZmdkIf...
# 3  https://api.spotify.com/v1/tracks/2cWdhA4ZDBvY...
# 4  https://api.spotify.com/v1/tracks/4voOsb8qpJ56...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0mDR...      291364
# 1  https://api.spotify.com/v1/audio-analysis/1tvi...      237107
# 2  https://api.spotify.com/v1/audio-analysis/5Ygy...      212006
# 3  https://api.spotify.com/v1/audio-analysis/2cWd...      198058
# 4  https://api.spotify.com/v1/audio-analysis/4voO...      261547
#
#   time_signature      genre
# 0              5  afrobeats
# 1              4  afrobeats
# 2              4  afrobeats
# 3              4  afrobeats
# 4              5  afrobeats
#
# [5 rows x 25 columns]

# %%
features = ['track_name','danceability','energy','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','genre']

# %%
df = df[features]

# %% [markdown]
# #### Quick clustering to see how the different genres seperate out

# %%
X = df.drop(columns = ['track_name','genre'])

# %%
pipeline = Pipeline([
                    ('scaler', StandardScaler()), 
                    ('kmeans', KMeans(n_clusters=10))
])

pipeline.fit(X)
df['cluster'] = pipeline.predict(X)

# %% [markdown]
# #### Using PCA reduce the features into 2 dimentions for better visualization

# %%
pipeline_pca = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=2))
])

# %%
pipeline_pca.fit(X)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=2))])

# %%
pca_df=pd.DataFrame(pipeline_pca.transform(X), columns=['x','y'])

# %%
pca_df['cluster'] = df['cluster']
pca_df['genre'] = df['genre']

# %%
plt.figure(figsize=(15,10))
sns.scatterplot( x=pca_df['x'], y=pca_df['y'], hue=pca_df['genre'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
# pipeline = Pipeline([
#             ('scaler', StandardScaler()),
#             ('tsne', TSNE(n_components=2, verbose=2))
# ])
# X_tnse = pipeline.fit_transform(X)


# tsne_df = pd.DataFrame(columns=['x', 'y'], data=X_tnse)
# tsne_df['genre'] = df['genre']
# tsne_df['cluster'] = df['cluster']
# tsne_df['track_name'] = df['track_name']

# %%
tsne_df.head()
# Out:
#            x          y      genre  cluster                 track_name
# 0 -10.616479 -36.213638  afrobeats        7        Oleku (feat. Brymo)
# 1  11.185565  17.538746  afrobeats        0                  Move Back
# 2  30.749006  18.547157  afrobeats        1                   Pakurumo
# 3  23.527344  12.602448  afrobeats        0  The Matter (feat. Wizkid)
# 4 -26.499306 -20.526506  afrobeats        2  Slow Down (feat. Wiz Kid)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot( x=tsne_df['x'], y=tsne_df['y'], hue=tsne_df['genre']);

# %% [markdown]
# #### This function gives the songs in each cluster

# %%
tsne_df[tsne_df['genre']=='ankita']
# Out:
#             x         y   genre  cluster  \
# 100 -1.269309 -0.465889  ankita        0
# 101 -3.656309 -0.687625  ankita        0
# 102 -4.062261 -4.899125  ankita        4
# 103  3.433677  3.276614  ankita        5
# 104 -5.414459  1.464719  ankita        4
# 105  0.889212  4.376725  ankita        5
# 106 -0.715433  4.979997  ankita        9
# 107 -4.046116 -5.136509  ankita        4
#
#                                 track_name
# 100  Haan Main Galat (From "Love Aaj Kal")
# 101                      Badal Pe Paon Hai
# 102                              Ziddi Dil
# 103                                 Dangal
# 104      Pray For Me (with Kendrick Lamar)
# 105                        Blinding Lights
# 106                 RAINY NIGHT IN TALLINN
# 107                                  Zinda

# %%
X.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
def get_song(df,title):
    cluster = df.loc[df['track_name'] == title, 'cluster'].iloc[0]
    lst=[]
    for i in range(len(df)):
        if df.loc[i]['cluster'] == cluster:
            lst.append(df.loc[i]['track_name'])
    return lst, cluster

# %% [markdown]
# ## Cosine similarity

# %%
X.head()
# Out:
#    danceability  energy  loudness  mode  speechiness  acousticness  \
# 0         0.544   0.730    -4.299     0       0.1440         0.344
# 1         0.793   0.734    -9.252     0       0.0981         0.323
# 2         0.879   0.737    -5.412     1       0.0421         0.525
# 3         0.697   0.841    -6.782     1       0.2710         0.224
# 4         0.520   0.717    -3.006     0       0.3890         0.116
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001     0.140    0.751  162.112
# 1          0.000002     0.777    0.793  125.032
# 2          0.005760     0.268    0.967  119.990
# 3          0.000000     0.336    0.808  103.070
# 4          0.000000     0.249    0.704  135.550

# %%
similarities = cosine_similarity(X)

# %%
similarities
# Out:
# array([[1.        , 0.99885823, 0.99977449, ..., 0.9999434 , 0.99762504,
#         0.99917263],
#        [0.99885823, 1.        , 0.99953946, ..., 0.99917993, 0.99969244,
#         0.99996123],
#        [0.99977449, 0.99953946, 1.        , ..., 0.99990238, 0.99870536,
#         0.99971158],
#        ...,
#        [0.9999434 , 0.99917993, 0.99990238, ..., 1.        , 0.99818375,
#         0.99944682],
#        [0.99762504, 0.99969244, 0.99870536, ..., 0.99818375, 1.        ,
#         0.99954636],
#        [0.99917263, 0.99996123, 0.99971158, ..., 0.99944682, 0.99954636,
#         1.        ]])

# %%
recommender_df = pd.DataFrame(similarities,
                              columns=df['track_name'],
                             index=df['track_name'])

# %%
recommender_df
# Out:
# track_name                         Oleku (feat. Brymo)  Move Back  Pakurumo  \
# track_name
# Oleku (feat. Brymo)                           1.000000   0.998858  0.999774
# Move Back                                     0.998858   1.000000  0.999539
# Pakurumo                                      0.999774   0.999539  1.000000
# The Matter (feat. Wizkid)                     0.999164   0.999910  0.999779
# Slow Down (feat. Wiz Kid)                     0.999987   0.998647  0.999683
# ...                                                ...        ...       ...
# Dangal                                        0.999997   0.998952  0.999806
# Pray For Me (with Kendrick Lamar)             0.999672   0.999628  0.999962
# Blinding Lights                               0.999943   0.999180  0.999902
# RAINY NIGHT IN TALLINN                        0.997625   0.999692  0.998705
# Zinda                                         0.999173   0.999961  0.999712
#
# track_name                         The Matter (feat. Wizkid)  \
# track_name
# Oleku (feat. Brymo)                                 0.999164
# Move Back                                           0.999910
# Pakurumo                                            0.999779
# The Matter (feat. Wizkid)                           1.000000
# Slow Down (feat. Wiz Kid)                           0.998992
# ...                                                      ...
# Dangal                                              0.999241
# Pray For Me (with Kendrick Lamar)                   0.999844
# Blinding Lights                                     0.999471
# RAINY NIGHT IN TALLINN                              0.999511
# Zinda                                               0.999942
#
# track_name                         Slow Down (feat. Wiz Kid)  Like to Party  \
# track_name
# Oleku (feat. Brymo)                                 0.999987       0.999251
# Move Back                                           0.998647       0.999889
# Pakurumo                                            0.999683       0.999807
# The Matter (feat. Wizkid)                           0.998992       0.999990
# Slow Down (feat. Wiz Kid)                           1.000000       0.999085
# ...                                                      ...            ...
# Dangal                                              0.999974       0.999327
# Pray For Me (with Kendrick Lamar)                   0.999564       0.999875
# Blinding Lights                                     0.999894       0.999547
# RAINY NIGHT IN TALLINN                              0.997315       0.999479
# Zinda                                               0.998990       0.999947
#
# track_name                          Yahooze  Bumper To Bumper  Dami Duro  \
# track_name
# Oleku (feat. Brymo)                0.999216          0.998757   0.999778
# Move Back                          0.999903          0.999984   0.997677
# Pakurumo                           0.999798          0.999463   0.999186
# The Matter (feat. Wizkid)          0.999992          0.999883   0.998159
# Slow Down (feat. Wiz Kid)          0.999044          0.998533   0.999862
# ...                                     ...               ...        ...
# Dangal                             0.999294          0.998861   0.999731
# Pray For Me (with Kendrick Lamar)  0.999868          0.999591   0.998991
# Blinding Lights                    0.999518          0.999110   0.999549
# RAINY NIGHT IN TALLINN             0.999497          0.999767   0.995997
# Zinda                              0.999956          0.999952   0.998131
#
# track_name                         Gongo Aso  ...    Wololo    Yes/No  \
# track_name                                    ...
# Oleku (feat. Brymo)                 0.999933  ...  0.999700  0.999835
# Move Back                           0.998740  ...  0.999707  0.999473
# Pakurumo                            0.999790  ...  0.999937  0.999985
# The Matter (feat. Wizkid)           0.999162  ...  0.999825  0.999723
# Slow Down (feat. Wiz Kid)           0.999933  ...  0.999588  0.999752
# ...                                      ...  ...       ...       ...
# Dangal                              0.999926  ...  0.999750  0.999865
# Pray For Me (with Kendrick Lamar)   0.999675  ...  0.999940  0.999960
# Blinding Lights                     0.999905  ...  0.999839  0.999954
# RAINY NIGHT IN TALLINN              0.997503  ...  0.998952  0.998625
# Zinda                               0.999065  ...  0.999863  0.999675
#
# track_name                         Haan Main Galat (From "Love Aaj Kal")  \
# track_name
# Oleku (feat. Brymo)                                             0.999726
# Move Back                                                       0.999611
# Pakurumo                                                        0.999988
# The Matter (feat. Wizkid)                                       0.999832
# Slow Down (feat. Wiz Kid)                                       0.999625
# ...                                                                  ...
# Dangal                                                          0.999767
# Pray For Me (with Kendrick Lamar)                               0.999980
# Blinding Lights                                                 0.999887
# RAINY NIGHT IN TALLINN                                          0.998858
# Zinda                                                           0.999780
#
# track_name                         Badal Pe Paon Hai  Ziddi Dil    Dangal  \
# track_name
# Oleku (feat. Brymo)                         0.997845   0.998789  0.999997
# Move Back                                   0.999785   0.999979  0.998952
# Pakurumo                                    0.998925   0.999490  0.999806
# The Matter (feat. Wizkid)                   0.999667   0.999897  0.999241
# Slow Down (feat. Wiz Kid)                   0.997558   0.998571  0.999974
# ...                                              ...        ...       ...
# Dangal                                      0.997979   0.998893  1.000000
# Pray For Me (with Kendrick Lamar)           0.999106   0.999606  0.999723
# Blinding Lights                             0.998365   0.999132  0.999962
# RAINY NIGHT IN TALLINN                      0.999929   0.999737  0.997772
# Zinda                                       0.999657   0.999963  0.999257
#
# track_name                         Pray For Me (with Kendrick Lamar)  \
# track_name
# Oleku (feat. Brymo)                                         0.999672
# Move Back                                                   0.999628
# Pakurumo                                                    0.999962
# The Matter (feat. Wizkid)                                   0.999844
# Slow Down (feat. Wiz Kid)                                   0.999564
# ...                                                              ...
# Dangal                                                      0.999723
# Pray For Me (with Kendrick Lamar)                           1.000000
# Blinding Lights                                             0.999870
# RAINY NIGHT IN TALLINN                                      0.998945
# Zinda                                                       0.999788
#
# track_name                         Blinding Lights  RAINY NIGHT IN TALLINN  \
# track_name
# Oleku (feat. Brymo)                       0.999943                0.997625
# Move Back                                 0.999180                0.999692
# Pakurumo                                  0.999902                0.998705
# The Matter (feat. Wizkid)                 0.999471                0.999511
# Slow Down (feat. Wiz Kid)                 0.999894                0.997315
# ...                                            ...                     ...
# Dangal                                    0.999962                0.997772
# Pray For Me (with Kendrick Lamar)         0.999870                0.998945
# Blinding Lights                           1.000000                0.998184
# RAINY NIGHT IN TALLINN                    0.998184                1.000000
# Zinda                                     0.999447                0.999546
#
# track_name                            Zinda
# track_name
# Oleku (feat. Brymo)                0.999173
# Move Back                          0.999961
# Pakurumo                           0.999712
# The Matter (feat. Wizkid)          0.999942
# Slow Down (feat. Wiz Kid)          0.998990
# ...                                     ...
# Dangal                             0.999257
# Pray For Me (with Kendrick Lamar)  0.999788
# Blinding Lights                    0.999447
# RAINY NIGHT IN TALLINN             0.999546
# Zinda                              1.000000
#
# [108 rows x 108 columns]
