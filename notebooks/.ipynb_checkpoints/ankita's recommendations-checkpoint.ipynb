# %% [markdown]
# # Afrobeats Recommender

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity
from sklearn.decomposition import PCA

from scipy import sparse
import plotly.express as px
import time

# %% [markdown]
# #### Import Ankita's Playlist

# %%
ankita= pd.read_csv('../data/ankita.csv')
ankita.head(2)
# Out:
#                 track_uri                             track_name  \
# 0  068HSvCf5MbQfhV4qqaelg  Haan Main Galat (From "Love Aaj Kal")
# 1  2aHz87L2Z4a0ZEQ7vMlH8z                      Badal Pe Paon Hai
#
#       artist_name              artist_uri  \
# 0          Pritam  1wRPtKGflJrBx9BmLsSwlU
# 1  Salim–Sulaiman  6ohaQzKaXrobAL8paLSaxq
#
#                                    album  track_pop  danceability  energy  \
# 0  Haan Main Galat (From "Love Aaj Kal")         64         0.685   0.736
# 1                          Chak De India         57         0.649   0.788
#
#    key  loudness  ...  valence    tempo            type  \
# 0    0    -5.656  ...    0.893  117.979  audio_features
# 1    9    -9.607  ...    0.869  104.999  audio_features
#
#                        id                                   uri  \
# 0  068HSvCf5MbQfhV4qqaelg  spotify:track:068HSvCf5MbQfhV4qqaelg
# 1  2aHz87L2Z4a0ZEQ7vMlH8z  spotify:track:2aHz87L2Z4a0ZEQ7vMlH8z
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/068HSvCf5MbQ...
# 1  https://api.spotify.com/v1/tracks/2aHz87L2Z4a0...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/068H...      218644
# 1  https://api.spotify.com/v1/audio-analysis/2aHz...      243931
#
#   time_signature   genre
# 0              4  ankita
# 1              4  ankita
#
# [2 rows x 25 columns]

# %%
ankita.shape
# Out:
# (8, 25)

# %%
afrobeats = pd.read_csv('../data/afrobeats.csv')
afrobeats.head(2)
# Out:
#                 track_uri           track_name artist_name  \
# 0  0mDRuZmReEm6DquPLJlcEm  Oleku (feat. Brymo)  Ice Prince
# 1  1tvi8tv0eykhNcV1WtaIqO            Move Back       5five
#
#                artist_uri                album  track_pop  danceability  \
# 0  1sSt1DqqqFLkPwfrqafVyn  Oleku (feat. Brymo)         51         0.544
# 1  37zb1JQnDV9dRLatrASEj1            Move Back         45         0.793
#
#    energy   key  loudness  ...  valence    tempo            type  \
# 0   0.730   1.0    -4.299  ...    0.751  162.112  audio_features
# 1   0.734  11.0    -9.252  ...    0.793  125.032  audio_features
#
#                        id                                   uri  \
# 0  0mDRuZmReEm6DquPLJlcEm  spotify:track:0mDRuZmReEm6DquPLJlcEm
# 1  1tvi8tv0eykhNcV1WtaIqO  spotify:track:1tvi8tv0eykhNcV1WtaIqO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0mDRuZmReEm6...
# 1  https://api.spotify.com/v1/tracks/1tvi8tv0eykh...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0mDR...    291364.0
# 1  https://api.spotify.com/v1/audio-analysis/1tvi...    237107.0
#
#   time_signature      genre
# 0            5.0  afrobeats
# 1            4.0  afrobeats
#
# [2 rows x 25 columns]

# %%
afrobeats.shape
# Out:
# (1874, 25)

# %%
df = pd.concat([afrobeats, ankita])

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#                 track_uri                 track_name   artist_name  \
# 0  0mDRuZmReEm6DquPLJlcEm        Oleku (feat. Brymo)    Ice Prince
# 1  1tvi8tv0eykhNcV1WtaIqO                  Move Back         5five
# 2  5YgyvTZmdkIfFOnj8ri8mZ                   Pakurumo        WizKid
# 3  2cWdhA4ZDBvYuHRKKIPT3k  The Matter (feat. Wizkid)  Maleek Berry
# 4  4voOsb8qpJ569JaMiGAyrl  Slow Down (feat. Wiz Kid)        R2Bees
#
#                artist_uri                                album  track_pop  \
# 0  1sSt1DqqqFLkPwfrqafVyn                  Oleku (feat. Brymo)         51
# 1  37zb1JQnDV9dRLatrASEj1                            Move Back         45
# 2  3tVQdUvClmAT7URs9V3rsp                            Superstar         49
# 3  520qA5VGL9iI0SbmEnTVNg            The Matter (feat. Wizkid)         49
# 4  0LFsP7WPfu5inz9a1amcE4  Refuse to Be Broke: Da Revolution 2         53
#
#    danceability  energy   key  loudness  ...  valence    tempo  \
# 0         0.544   0.730   1.0    -4.299  ...    0.751  162.112
# 1         0.793   0.734  11.0    -9.252  ...    0.793  125.032
# 2         0.879   0.737   2.0    -5.412  ...    0.967  119.990
# 3         0.697   0.841   2.0    -6.782  ...    0.808  103.070
# 4         0.520   0.717   6.0    -3.006  ...    0.704  135.550
#
#              type                      id  \
# 0  audio_features  0mDRuZmReEm6DquPLJlcEm
# 1  audio_features  1tvi8tv0eykhNcV1WtaIqO
# 2  audio_features  5YgyvTZmdkIfFOnj8ri8mZ
# 3  audio_features  2cWdhA4ZDBvYuHRKKIPT3k
# 4  audio_features  4voOsb8qpJ569JaMiGAyrl
#
#                                     uri  \
# 0  spotify:track:0mDRuZmReEm6DquPLJlcEm
# 1  spotify:track:1tvi8tv0eykhNcV1WtaIqO
# 2  spotify:track:5YgyvTZmdkIfFOnj8ri8mZ
# 3  spotify:track:2cWdhA4ZDBvYuHRKKIPT3k
# 4  spotify:track:4voOsb8qpJ569JaMiGAyrl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0mDRuZmReEm6...
# 1  https://api.spotify.com/v1/tracks/1tvi8tv0eykh...
# 2  https://api.spotify.com/v1/tracks/5YgyvTZmdkIf...
# 3  https://api.spotify.com/v1/tracks/2cWdhA4ZDBvY...
# 4  https://api.spotify.com/v1/tracks/4voOsb8qpJ56...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0mDR...    291364.0
# 1  https://api.spotify.com/v1/audio-analysis/1tvi...    237107.0
# 2  https://api.spotify.com/v1/audio-analysis/5Ygy...    212006.0
# 3  https://api.spotify.com/v1/audio-analysis/2cWd...    198058.0
# 4  https://api.spotify.com/v1/audio-analysis/4voO...    261547.0
#
#   time_signature      genre
# 0            5.0  afrobeats
# 1            4.0  afrobeats
# 2            4.0  afrobeats
# 3            4.0  afrobeats
# 4            5.0  afrobeats
#
# [5 rows x 25 columns]

# %%
features = ['danceability','energy','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']

# %% [markdown]
# #### Quick clustering to see how the different genres seperate out

# %%
X = df[features]

# %%
pipeline = Pipeline([
                    ('scaler', StandardScaler()), 
                    ('kmeans', KMeans(n_clusters=200))
])

pipeline.fit(X)
df['cluster'] = pipeline.predict(X)

# %%
df[df['cluster']==6]
# Out:
#                    track_uri                       track_name  \
# 167   6Bl5ov7N6sw7MetxdtafFT  Lova Lova (feat. Duncan Mighty)
# 325   5BkBcXJ0rDRlnzh3tmknxI             Party With A Jagaban
# 414   2hRazi6Y5U8NuYK1x1ECk0                         Personal
# 432   2L82lo8nCN4JT6BdWNKNEg                   Ozumba Mbadiwe
# 480   23tZbR3A6G52shxX4CQg92                  Twisted Fantasy
# 496   5pvhNfGaLFkODASTarNO5v                        Back2Back
# 510   7DKJ72R0ekTMoxaToI4Mgg                   Barawo - Remix
# 591   3VqCsVD7KaKSKEPYco4P8S                             Boyz
# 658   43KfooASeXXuMRJhvgLipo                       Ma Doubt E
# 673   6ZEXpYYjKX33hXjeZK0sNH            If E Happen For Lagos
# 833   4C0dBjF3xoqF3wGWO2r9k9                    Falling For U
# 840   23f5XFt8ITHfcsTSqKVzui            If E Happen For Lagos
# 858   00QJNRiXuI2zTlPCwUpg54                          falling
# 945   4sh6VEmaZBqVN4XEvnev86  Non Living Thing (feat. Oxlade)
# 1069  41lOWkUA0N9fU4PKRKyUVt  Back2Back (feat. Bella Shmurda)
# 1108  39RFbhX6RVTnXn2ml9yVbK                            Ruger
# 1295  1OV9hRdiyYDuRayvO9QQzT                   Overdose Remix
# 1316  2gSBzguJZzHSMEP9snKgyf                           Barawo
# 1474  6fVj2ejevsVvHzWpumuKOG                          Benzema
# 1736  49skbcyEISDXWr74knzlLf                        Baby Girl
# 1842  4NLFnAPoMAiuuK8iXnit6W                   Ozumba Mbadiwe
# 1860  6txMfhCu1LqV6eNqTzUk0s                           Nobody
#
#             artist_name              artist_uri  \
# 167         Tiwa Savage  1hNaHKp2Za5YdOAG0WnRbc
# 325   Midas the Jagaban  07MX7XJsNTn8JlgEcbZ7Fd
# 414              Fiokee  0dIKXNriGyVYvw6Cw2jko5
# 432       Reekado Banks  3bxZkzk0PLHcetO9o4oxXn
# 480        Justine Skye  0jUQSUOcM7lxVn5eVGTkzQ
# 496              Rexxie  5z207JpMeX1oCYVvMKReku
# 510      Ajebo Hustlers  7oVwzvvrXEC8LbXhaNjTi4
# 591          Yemi Alade  7fKO99ryLDo8VocdtVvwZW
# 658             Skiibii  72Z2AhMKpxZjLNnPMyinUE
# 673              Favour  1gJMfObFr0ilBTmEsHypau
# 833         Blaq Jerzee  4on7a4BKixLl1rSlEcaY8Y
# 840             Runtown  6mMtnxEQkYoY5FfJIQ9Rhb
# 858       Dayonthetrack  7vsaQwuPAG2PSWPVitnXrc
# 945            Sarkodie  01DTVE3KmoPogPZaOvMqO8
# 1069             Rexxie  5z207JpMeX1oCYVvMKReku
# 1108              Ruger  0a1SidMjD8D6EHvJph4n2H
# 1295             Dunnie  5q1uxBdFXCDZDdNOw2rzD2
# 1316     Ajebo Hustlers  7oVwzvvrXEC8LbXhaNjTi4
# 1474              Guchi  0PC3YLVMq3svBBqVtgrDI9
# 1736          Strongman  4ISHXrztVcONj4mQCnwCs9
# 1842      Reekado Banks  3bxZkzk0PLHcetO9o4oxXn
# 1860          JaySynths  5Dw7QRpfWxXgx5GIKbu8zZ
#
#                                 album  track_pop  danceability  energy   key  \
# 167   Lova Lova (feat. Duncan Mighty)         48         0.741   0.725   2.0
# 325              Party With A Jagaban         73         0.826   0.795   7.0
# 414                          Personal         42         0.782   0.883   9.0
# 432                         OTR Vol.2         36         0.784   0.785   5.0
# 480                   Twisted Fantasy         45         0.783   0.859  10.0
# 496                         Back2Back         13         0.825   0.797   5.0
# 510                    Barawo (Remix)         39         0.852   0.792   8.0
# 591                              Boyz         44         0.800   0.841  10.0
# 658            God is Bigger Than Man         31         0.817   0.817   9.0
# 673             If E Happen For Lagos         43         0.758   0.755  10.0
# 833                     Falling For U         72         0.839   0.810  10.0
# 840             If E Happen For Lagos         46         0.745   0.792   3.0
# 858                           falling         14         0.731   0.854   5.0
# 945                       No Pressure          0         0.795   0.715   9.0
# 1069                  A True Champion         25         0.825   0.798   5.0
# 1108                            Ruger         46         0.724   0.805  10.0
# 1295                   Overdose Remix          0         0.772   0.847   0.0
# 1316                           Barawo         31         0.839   0.800   8.0
# 1474                          Benzema         45         0.738   0.802   0.0
# 1736                        Baby Girl         29         0.802   0.687   7.0
# 1842                   Ozumba Mbadiwe         66         0.785   0.782   5.0
# 1860                           Nobody          0         0.714   0.800   0.0
#
#       loudness  ...    tempo            type                      id  \
# 167     -4.436  ...   98.916  audio_features  6Bl5ov7N6sw7MetxdtafFT
# 325     -3.550  ...  117.006  audio_features  5BkBcXJ0rDRlnzh3tmknxI
# 414     -4.766  ...  115.013  audio_features  2hRazi6Y5U8NuYK1x1ECk0
# 432     -6.794  ...  109.965  audio_features  2L82lo8nCN4JT6BdWNKNEg
# 480     -5.712  ...  100.990  audio_features  23tZbR3A6G52shxX4CQg92
# 496     -5.334  ...  122.970  audio_features  5pvhNfGaLFkODASTarNO5v
# 510     -2.923  ...  111.167  audio_features  7DKJ72R0ekTMoxaToI4Mgg
# 591     -3.771  ...  100.000  audio_features  3VqCsVD7KaKSKEPYco4P8S
# 658     -4.879  ...  112.043  audio_features  43KfooASeXXuMRJhvgLipo
# 673     -5.631  ...   92.022  audio_features  6ZEXpYYjKX33hXjeZK0sNH
# 833     -4.297  ...  104.011  audio_features  4C0dBjF3xoqF3wGWO2r9k9
# 840     -4.944  ...   92.033  audio_features  23f5XFt8ITHfcsTSqKVzui
# 858     -4.431  ...  100.038  audio_features  00QJNRiXuI2zTlPCwUpg54
# 945     -4.923  ...  106.932  audio_features  4sh6VEmaZBqVN4XEvnev86
# 1069    -5.334  ...  122.965  audio_features  41lOWkUA0N9fU4PKRKyUVt
# 1108    -6.395  ...  103.029  audio_features  39RFbhX6RVTnXn2ml9yVbK
# 1295    -5.726  ...  103.029  audio_features  1OV9hRdiyYDuRayvO9QQzT
# 1316    -2.651  ...  111.016  audio_features  2gSBzguJZzHSMEP9snKgyf
# 1474    -5.420  ...   95.089  audio_features  6fVj2ejevsVvHzWpumuKOG
# 1736    -3.840  ...  105.057  audio_features  49skbcyEISDXWr74knzlLf
# 1842    -6.803  ...  109.961  audio_features  4NLFnAPoMAiuuK8iXnit6W
# 1860    -5.261  ...  101.998  audio_features  6txMfhCu1LqV6eNqTzUk0s
#
#                                        uri  \
# 167   spotify:track:6Bl5ov7N6sw7MetxdtafFT
# 325   spotify:track:5BkBcXJ0rDRlnzh3tmknxI
# 414   spotify:track:2hRazi6Y5U8NuYK1x1ECk0
# 432   spotify:track:2L82lo8nCN4JT6BdWNKNEg
# 480   spotify:track:23tZbR3A6G52shxX4CQg92
# 496   spotify:track:5pvhNfGaLFkODASTarNO5v
# 510   spotify:track:7DKJ72R0ekTMoxaToI4Mgg
# 591   spotify:track:3VqCsVD7KaKSKEPYco4P8S
# 658   spotify:track:43KfooASeXXuMRJhvgLipo
# 673   spotify:track:6ZEXpYYjKX33hXjeZK0sNH
# 833   spotify:track:4C0dBjF3xoqF3wGWO2r9k9
# 840   spotify:track:23f5XFt8ITHfcsTSqKVzui
# 858   spotify:track:00QJNRiXuI2zTlPCwUpg54
# 945   spotify:track:4sh6VEmaZBqVN4XEvnev86
# 1069  spotify:track:41lOWkUA0N9fU4PKRKyUVt
# 1108  spotify:track:39RFbhX6RVTnXn2ml9yVbK
# 1295  spotify:track:1OV9hRdiyYDuRayvO9QQzT
# 1316  spotify:track:2gSBzguJZzHSMEP9snKgyf
# 1474  spotify:track:6fVj2ejevsVvHzWpumuKOG
# 1736  spotify:track:49skbcyEISDXWr74knzlLf
# 1842  spotify:track:4NLFnAPoMAiuuK8iXnit6W
# 1860  spotify:track:6txMfhCu1LqV6eNqTzUk0s
#
#                                              track_href  \
# 167   https://api.spotify.com/v1/tracks/6Bl5ov7N6sw7...
# 325   https://api.spotify.com/v1/tracks/5BkBcXJ0rDRl...
# 414   https://api.spotify.com/v1/tracks/2hRazi6Y5U8N...
# 432   https://api.spotify.com/v1/tracks/2L82lo8nCN4J...
# 480   https://api.spotify.com/v1/tracks/23tZbR3A6G52...
# 496   https://api.spotify.com/v1/tracks/5pvhNfGaLFkO...
# 510   https://api.spotify.com/v1/tracks/7DKJ72R0ekTM...
# 591   https://api.spotify.com/v1/tracks/3VqCsVD7KaKS...
# 658   https://api.spotify.com/v1/tracks/43KfooASeXXu...
# 673   https://api.spotify.com/v1/tracks/6ZEXpYYjKX33...
# 833   https://api.spotify.com/v1/tracks/4C0dBjF3xoqF...
# 840   https://api.spotify.com/v1/tracks/23f5XFt8ITHf...
# 858   https://api.spotify.com/v1/tracks/00QJNRiXuI2z...
# 945   https://api.spotify.com/v1/tracks/4sh6VEmaZBqV...
# 1069  https://api.spotify.com/v1/tracks/41lOWkUA0N9f...
# 1108  https://api.spotify.com/v1/tracks/39RFbhX6RVTn...
# 1295  https://api.spotify.com/v1/tracks/1OV9hRdiyYDu...
# 1316  https://api.spotify.com/v1/tracks/2gSBzguJZzHS...
# 1474  https://api.spotify.com/v1/tracks/6fVj2ejevsVv...
# 1736  https://api.spotify.com/v1/tracks/49skbcyEISDX...
# 1842  https://api.spotify.com/v1/tracks/4NLFnAPoMAiu...
# 1860  https://api.spotify.com/v1/tracks/6txMfhCu1LqV...
#
#                                            analysis_url  duration_ms  \
# 167   https://api.spotify.com/v1/audio-analysis/6Bl5...     218253.0
# 325   https://api.spotify.com/v1/audio-analysis/5BkB...     201026.0
# 414   https://api.spotify.com/v1/audio-analysis/2hRa...     179473.0
# 432   https://api.spotify.com/v1/audio-analysis/2L82...     212636.0
# 480   https://api.spotify.com/v1/audio-analysis/23tZ...     187923.0
# 496   https://api.spotify.com/v1/audio-analysis/5pvh...     175610.0
# 510   https://api.spotify.com/v1/audio-analysis/7DKJ...     211958.0
# 591   https://api.spotify.com/v1/audio-analysis/3VqC...     214000.0
# 658   https://api.spotify.com/v1/audio-analysis/43Kf...     139468.0
# 673   https://api.spotify.com/v1/audio-analysis/6ZEX...     211306.0
# 833   https://api.spotify.com/v1/audio-analysis/4C0d...     181965.0
# 840   https://api.spotify.com/v1/audio-analysis/23f5...     211302.0
# 858   https://api.spotify.com/v1/audio-analysis/00QJ...     170220.0
# 945   https://api.spotify.com/v1/audio-analysis/4sh6...     229346.0
# 1069  https://api.spotify.com/v1/audio-analysis/41lO...     175610.0
# 1108  https://api.spotify.com/v1/audio-analysis/39RF...     191175.0
# 1295  https://api.spotify.com/v1/audio-analysis/1OV9...     177087.0
# 1316  https://api.spotify.com/v1/audio-analysis/2gSB...     229251.0
# 1474  https://api.spotify.com/v1/audio-analysis/6fVj...     166737.0
# 1736  https://api.spotify.com/v1/audio-analysis/49sk...     248376.0
# 1842  https://api.spotify.com/v1/audio-analysis/4NLF...     212636.0
# 1860  https://api.spotify.com/v1/audio-analysis/6txM...     192993.0
#
#      time_signature      genre cluster
# 167             4.0  afrobeats       6
# 325             4.0  afrobeats       6
# 414             4.0  afrobeats       6
# 432             4.0  afrobeats       6
# 480             4.0  afrobeats       6
# 496             4.0  afrobeats       6
# 510             4.0  afrobeats       6
# 591             4.0  afrobeats       6
# 658             4.0  afrobeats       6
# 673             4.0  afrobeats       6
# 833             4.0  afrobeats       6
# 840             4.0  afrobeats       6
# 858             4.0  afrobeats       6
# 945             4.0  afrobeats       6
# 1069            4.0  afrobeats       6
# 1108            4.0  afrobeats       6
# 1295            4.0  afrobeats       6
# 1316            4.0  afrobeats       6
# 1474            4.0  afrobeats       6
# 1736            4.0  afrobeats       6
# 1842            4.0  afrobeats       6
# 1860            4.0  afrobeats       6
#
# [22 rows x 26 columns]

# %% [markdown]
# #### Using PCA reduce the features into 2 dimentions for better visualization

# %%
pipeline_pca = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=2))
])

# %%
pipeline_pca.fit(X)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=2))])

# %%
pca_df=pd.DataFrame(pipeline_pca.transform(X), columns=['x','y'])

# %%
pca_df['cluster'] = df['cluster']
pca_df['genre'] = df['genre']

# %%
plt.figure(figsize=(15,10))
sns.scatterplot( x=pca_df['x'], y=pca_df['y'], hue=pca_df['genre'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('tsne', TSNE(n_components=2, verbose=False))
])
X_tnse = pipeline.fit_transform(X)


tsne_df = pd.DataFrame(columns=['x', 'y'], data=X_tnse)
tsne_df['genre'] = df['genre']
tsne_df['cluster'] = df['cluster']
tsne_df['track_name'] = df['track_name']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne_df.head()
# Out:
#            x          y      genre  cluster                 track_name
# 0 -14.823277 -43.360474  afrobeats        2        Oleku (feat. Brymo)
# 1  -1.141327  29.808302  afrobeats        7                  Move Back
# 2  22.061064  26.939848  afrobeats        8                   Pakurumo
# 3  15.039465  17.415808  afrobeats        7  The Matter (feat. Wizkid)
# 4 -27.558252 -24.842472  afrobeats        5  Slow Down (feat. Wiz Kid)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot( x=tsne_df['x'], y=tsne_df['y'], hue=tsne_df['genre']);

# %% [markdown]
# #### This function gives the songs in each cluster

# %%
tsne_df[tsne_df['genre']=='ankita']
# Out:
#               x          y   genre  cluster  \
# 1874  47.451046  -4.335578  ankita        0
# 1875  43.585773  -2.690656  ankita        0
# 1876 -21.518208   0.492531  ankita        9
# 1877 -11.479328 -42.469315  ankita        2
# 1878  28.191635   9.209949  ankita        9
# 1879   5.771981 -40.545475  ankita        2
# 1880   8.325590  54.180443  ankita        1
# 1881 -22.692701  -2.650461  ankita        9
#
#                                  track_name
# 1874  Haan Main Galat (From "Love Aaj Kal")
# 1875                      Badal Pe Paon Hai
# 1876                              Ziddi Dil
# 1877                                 Dangal
# 1878      Pray For Me (with Kendrick Lamar)
# 1879                        Blinding Lights
# 1880                 RAINY NIGHT IN TALLINN
# 1881                                  Zinda

# %%
X.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
def get_song(df,title):
    cluster = df.loc[df['track_name'] == title, 'cluster'].iloc[0]
    lst=[]
    for i in range(len(df)):
        if df.loc[i]['cluster'] == cluster:
            lst.append(df.loc[i]['track_name'])
    return lst, cluster

# %% [markdown]
# ## Cosine similarity

# %%
X.head()
# Out:
#    danceability  energy  loudness  mode  speechiness  acousticness  \
# 0         0.544   0.730    -4.299   0.0       0.1440         0.344
# 1         0.793   0.734    -9.252   0.0       0.0981         0.323
# 2         0.879   0.737    -5.412   1.0       0.0421         0.525
# 3         0.697   0.841    -6.782   1.0       0.2710         0.224
# 4         0.520   0.717    -3.006   0.0       0.3890         0.116
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001     0.140    0.751  162.112
# 1          0.000002     0.777    0.793  125.032
# 2          0.005760     0.268    0.967  119.990
# 3          0.000000     0.336    0.808  103.070
# 4          0.000000     0.249    0.704  135.550

# %%
similarities = cosine_similarity(X)

# %%
similarities
# Out:
# array([[1.        , 0.99885823, 0.99977449, ..., 0.9999434 , 0.99762504,
#         0.99917263],
#        [0.99885823, 1.        , 0.99953946, ..., 0.99917993, 0.99969244,
#         0.99996123],
#        [0.99977449, 0.99953946, 1.        , ..., 0.99990238, 0.99870536,
#         0.99971158],
#        ...,
#        [0.9999434 , 0.99917993, 0.99990238, ..., 1.        , 0.99818375,
#         0.99944682],
#        [0.99762504, 0.99969244, 0.99870536, ..., 0.99818375, 1.        ,
#         0.99954636],
#        [0.99917263, 0.99996123, 0.99971158, ..., 0.99944682, 0.99954636,
#         1.        ]])

# %%
recommender_df = pd.DataFrame(similarities,
                              columns=df['track_name'],
                             index=df['track_name']).drop(ankita['track_name'])

# %%
recommender_df.head(3)
# Out:
# track_name           Oleku (feat. Brymo)  Move Back  Pakurumo  \
# track_name
# Oleku (feat. Brymo)             1.000000   0.998858  0.999774
# Move Back                       0.998858   1.000000  0.999539
# Pakurumo                        0.999774   0.999539  1.000000
#
# track_name           The Matter (feat. Wizkid)  Slow Down (feat. Wiz Kid)  \
# track_name
# Oleku (feat. Brymo)                   0.999164                   0.999987
# Move Back                             0.999910                   0.998647
# Pakurumo                              0.999779                   0.999683
#
# track_name           Like to Party   Yahooze  Bumper To Bumper  Dami Duro  \
# track_name
# Oleku (feat. Brymo)       0.999251  0.999216          0.998757   0.999778
# Move Back                 0.999889  0.999903          0.999984   0.997677
# Pakurumo                  0.999807  0.999798          0.999463   0.999186
#
# track_name           Gongo Aso  ...  Le temps  Ozumba Mbadiwe - Remix  \
# track_name                      ...
# Oleku (feat. Brymo)   0.999933  ...  0.999259                0.998616
# Move Back             0.998740  ...  0.999942                0.999966
# Pakurumo              0.999790  ...  0.999769                0.999382
#
# track_name           Haan Main Galat (From "Love Aaj Kal")  Badal Pe Paon Hai  \
# track_name
# Oleku (feat. Brymo)                               0.999726           0.997845
# Move Back                                         0.999611           0.999785
# Pakurumo                                          0.999988           0.998925
#
# track_name           Ziddi Dil    Dangal  Pray For Me (with Kendrick Lamar)  \
# track_name
# Oleku (feat. Brymo)   0.998789  0.999997                           0.999672
# Move Back             0.999979  0.998952                           0.999628
# Pakurumo              0.999490  0.999806                           0.999962
#
# track_name           Blinding Lights  RAINY NIGHT IN TALLINN     Zinda
# track_name
# Oleku (feat. Brymo)         0.999943                0.997625  0.999173
# Move Back                   0.999180                0.999692  0.999961
# Pakurumo                    0.999902                0.998705  0.999712
#
# [3 rows x 1882 columns]

# %% [markdown]
# #### Create a function to predict top ten Afrobeats songs based on the playlist given

# %%
recommender_df['Zinda'].sort_values(ascending=False).index[0:10]
# Out:
# Index(['Who Dey Eat', 'Blow My Mind', 'Yawa (feat. Sarkodie)',
#        'Ginger (feat. Burna Boy)', 'Know Your Worth (feat. Davido & Tems)',
#        'Let It Go - DJ Boat Remix', 'Abena', 'Bounce It', 'Jabole',
#        'Ogaranya'],
#       dtype='object', name='track_name')

# %%
def recommend_afrobeats(track_names):
    top_ten_df = pd.DataFrame(columns=df.columns)
    top_ten_list = []
    
    #Get song from users playlis
    for track in track_names:
        
        
        for count in range(len(df)): 
            most_similar = recommender_df[track].sort_values(ascending=False).index[count]
            
            #check if song has already been recommended
            if most_similar in top_ten_list:
                continue
            
            else:
                top_ten_list.append(most_similar)
                break
                
        #create a dataframe of the recommended songs
        top_ten_df = pd.concat([top_ten_df, df[df['track_name']==most_similar]])
        
    return top_ten_df

# %%
recommend_afrobeats(ankita['track_name'])
# Out:
#                    track_uri                     track_name    artist_name  \
# 1682  0VgfzD2X7It9z04N9gpOTK                      Aku Shika   Kuami Eugene
# 309   79P1sxrpp1phhTgF1gkaI8     Italy (feat. Blaq Diamond)  BNXN fka Buju
# 1096  5IBkCmsOADHUFpow9kf9GB  Understanding Love - Extended     DarkoVibes
# 753   5xuiSfuLAJyaSqxocf3O17                     My Darlina    King Perryy
# 529   398G0odwKJ892uyEYDlMBh                  Onyeka (Baby)      Burna Boy
# 1002  7wXT3Oc16Q629MOZHKl3NJ                           Lady          Arrzy
# 1386  5BYCsDKV8ulLKdEYXsoHur                    Sugar Daddy    DJ Enimoney
# 1792  0Rhn8sbadn3pXK0xP9fyXt                    Sugar Daddy           KiDi
# 1799  680lETWgYaHdQt8847XsvV                    Who Dey Eat         Shaker
#
#                   artist_uri                          album track_pop  \
# 1682  0GGKrcPOlBkmBzQDf2Ogkl                       Rockstar        27
# 309   3zaDigUwjHvjOkSn0NDf9x     Italy (feat. Blaq Diamond)        66
# 1096  5a3kizlLAxR0P6qZEti8T8  Understanding Love (Extended)        22
# 753   2Srxd4jkUb5hcZEJO1SPnW                     My Darlina        31
# 529   3wcj11K77LjEY1PkEazffa                  Twice As Tall        53
# 1002  69WZ1pz2CpbDspDTOY8fEY                           Lady        25
# 1386  7nEYJ01WxrTl3kAklzEC61                    Sugar Daddy        35
# 1792  14PimM6ohO2gYftuwTam9V                          Sugar        28
# 1799  5I1G1MSxXh3zrZsVZCPzZj                    Who Dey Eat        24
#
#      danceability energy   key loudness  ...    tempo            type  \
# 1682        0.848  0.827  11.0   -6.381  ...   130.06  audio_features
# 309         0.837  0.693  11.0   -10.26  ...  112.969  audio_features
# 1096        0.696  0.682  11.0   -7.064  ...   95.987  audio_features
# 753         0.657  0.749   5.0   -5.419  ...  194.228  audio_features
# 529         0.825  0.685   2.0    -5.21  ...   102.03  audio_features
# 1002        0.529  0.712   5.0    -6.42  ...  194.057  audio_features
# 1386         0.91  0.559   1.0  -10.883  ...  114.005  audio_features
# 1792        0.762  0.761   0.0   -5.392  ...   99.989  audio_features
# 1799         0.75  0.788  11.0   -9.402  ...  140.009  audio_features
#
#                           id                                   uri  \
# 1682  0VgfzD2X7It9z04N9gpOTK  spotify:track:0VgfzD2X7It9z04N9gpOTK
# 309   79P1sxrpp1phhTgF1gkaI8  spotify:track:79P1sxrpp1phhTgF1gkaI8
# 1096  5IBkCmsOADHUFpow9kf9GB  spotify:track:5IBkCmsOADHUFpow9kf9GB
# 753   5xuiSfuLAJyaSqxocf3O17  spotify:track:5xuiSfuLAJyaSqxocf3O17
# 529   398G0odwKJ892uyEYDlMBh  spotify:track:398G0odwKJ892uyEYDlMBh
# 1002  7wXT3Oc16Q629MOZHKl3NJ  spotify:track:7wXT3Oc16Q629MOZHKl3NJ
# 1386  5BYCsDKV8ulLKdEYXsoHur  spotify:track:5BYCsDKV8ulLKdEYXsoHur
# 1792  0Rhn8sbadn3pXK0xP9fyXt  spotify:track:0Rhn8sbadn3pXK0xP9fyXt
# 1799  680lETWgYaHdQt8847XsvV  spotify:track:680lETWgYaHdQt8847XsvV
#
#                                              track_href  \
# 1682  https://api.spotify.com/v1/tracks/0VgfzD2X7It9...
# 309   https://api.spotify.com/v1/tracks/79P1sxrpp1ph...
# 1096  https://api.spotify.com/v1/tracks/5IBkCmsOADHU...
# 753   https://api.spotify.com/v1/tracks/5xuiSfuLAJya...
# 529   https://api.spotify.com/v1/tracks/398G0odwKJ89...
# 1002  https://api.spotify.com/v1/tracks/7wXT3Oc16Q62...
# 1386  https://api.spotify.com/v1/tracks/5BYCsDKV8ulL...
# 1792  https://api.spotify.com/v1/tracks/0Rhn8sbadn3p...
# 1799  https://api.spotify.com/v1/tracks/680lETWgYaHd...
#
#                                            analysis_url duration_ms  \
# 1682  https://api.spotify.com/v1/audio-analysis/0Vgf...    214615.0
# 309   https://api.spotify.com/v1/audio-analysis/79P1...    188395.0
# 1096  https://api.spotify.com/v1/audio-analysis/5IBk...    240600.0
# 753   https://api.spotify.com/v1/audio-analysis/5xui...    180000.0
# 529   https://api.spotify.com/v1/audio-analysis/398G...    202147.0
# 1002  https://api.spotify.com/v1/audio-analysis/7wXT...    202268.0
# 1386  https://api.spotify.com/v1/audio-analysis/5BYC...    153684.0
# 1792  https://api.spotify.com/v1/audio-analysis/0Rhn...    190200.0
# 1799  https://api.spotify.com/v1/audio-analysis/680l...    246857.0
#
#      time_signature      genre cluster
# 1682            4.0  afrobeats       0
# 309             4.0  afrobeats       6
# 1096            4.0  afrobeats       9
# 753             4.0  afrobeats       2
# 529             4.0  afrobeats       9
# 1002            4.0  afrobeats       2
# 1386            4.0  afrobeats       1
# 1792            4.0  afrobeats       7
# 1799            4.0  afrobeats       4
#
# [9 rows x 26 columns]
